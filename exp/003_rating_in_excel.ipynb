# %% [markdown]
# ## Exp 3: Export to excel for manual rating

# %% [markdown]
# This file exports the augmented dataframe to an excel and reads it back in.

# %%
import pandas as pd
EXCEL_PATH = '../dat/augmented_examples_shuffled.xlsx'
JSON_PATH = '../dat/augmented_examples_shuffled.json'

# %%
df = pd.read_json('../dat/egpaugmented.json')

# %%
df.head()
# Out:
#          # SuperCategory     SubCategory Level  Lexical Range  \
# 1101  1102         VERBS         linking    A1            NaN
# 871    872       PRESENT  present simple    A2            2.0
# 909    910      PRONOUNS       reflexive    B1            2.0
# 1103  1104         VERBS         linking    B2            3.0
# 272    273  CONJUNCTIONS    coordinating    C1            NaN
#
#                                            guideword  \
# 1101                         FORM: 'BE' + COMPLEMENT
# 871                                  FORM: NEGATIVE
# 909         FORM: SAME SUBJECT AND OBJECT, SINGULAR
# 1103                      FORM: LINKING + COMPLEMENT
# 272   FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
#
#                                        Can-do statement  \
# 1101        Can use linking verb 'be' with complements.
# 871   Can use the negative form with an increasing r...
# 909   Can use an increasing range of singular reflex...
# 1103  Can use a wide range of linking verbs with com...
# 272   Can use inverted auxiliary 'do' + the subject ...
#
#                                                 Example  \
# 1101  Because today is my birthday. (A1 BREAKTHROUGH...
# 871   I don't need the video because I've got the DV...
# 909   I decided to talk to him and introduce myself....
# 1103  There are indeed many ways of doing this and i...
# 272   Indeed, not only did they teach us useful know...
#
#                                                  prompt  \
# 1101  Create 20 more examples for the grammatical co...
# 871   Create 20 more examples for the grammatical co...
# 909   Create 20 more examples for the grammatical co...
# 1103  Create 20 more examples for the grammatical co...
# 272   Create 20 more examples for the grammatical co...
#
#                                      augmented_examples  \
# 1101  [The weather is sunny today., She is a doctor....
# 871   [I don't like coffee, I prefer tea., She doesn...
# 909   [He bought himself a new car for his birthday....
# 1103  [The movie seems really interesting but ends u...
# 272   [Not only did she win the race, but she also b...
#
#                             augmented_negative_examples
# 1101  [Today feels like a sunny day., Martin comes f...
# 871   [I need the video because I don't have the DVD...
# 909   [He bought a new car for his birthday., She co...
# 1103  [This can be a little bit strange, but the foo...
# 272   [They not only taught us useful knowledge, but...

# %% [markdown]
# Concat all examples, maintaining if they are positive or negative examples.

# %%
df['augmented_examples'] = df['augmented_examples'].apply(lambda examples: list(zip([True] * len(examples), examples)))
df['augmented_negative_examples'] = df['augmented_negative_examples'].apply(lambda examples: list(zip([False] * len(examples), examples)))
df['all_examples'] = df['augmented_examples'] + df['augmented_negative_examples']
df['all_examples']
# Out:
# 1101    [(True, The weather is sunny today.), (True, S...
# 871     [(True, I don't like coffee, I prefer tea.), (...
# 909     [(True, He bought himself a new car for his bi...
# 1103    [(True, The movie seems really interesting but...
# 272     [(True, Not only did she win the race, but she...
# 314     [(True, She was telling me about this incredib...
# Name: all_examples, dtype: object

# %% [markdown]
# Create one row per example

# %%
new_df = df.explode('all_examples').drop(['augmented_examples', 'augmented_negative_examples', 'prompt'], axis=1, inplace=False)
new_df = new_df.groupby('#').apply(lambda x: x.sample(frac=1)).reset_index(drop=True)
new_df
# Out:
#         # SuperCategory   SubCategory Level  Lexical Range  \
# 0     273  CONJUNCTIONS  coordinating    C1            NaN
# 1     273  CONJUNCTIONS  coordinating    C1            NaN
# 2     273  CONJUNCTIONS  coordinating    C1            NaN
# 3     273  CONJUNCTIONS  coordinating    C1            NaN
# 4     273  CONJUNCTIONS  coordinating    C1            NaN
# ..    ...           ...           ...   ...            ...
# 233  1104         VERBS       linking    B2            3.0
# 234  1104         VERBS       linking    B2            3.0
# 235  1104         VERBS       linking    B2            3.0
# 236  1104         VERBS       linking    B2            3.0
# 237  1104         VERBS       linking    B2            3.0
#
#                                           guideword  \
# 0    FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 1    FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 2    FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 3    FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 4    FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# ..                                              ...
# 233                      FORM: LINKING + COMPLEMENT
# 234                      FORM: LINKING + COMPLEMENT
# 235                      FORM: LINKING + COMPLEMENT
# 236                      FORM: LINKING + COMPLEMENT
# 237                      FORM: LINKING + COMPLEMENT
#
#                                       Can-do statement  \
# 0    Can use inverted auxiliary 'do' + the subject ...
# 1    Can use inverted auxiliary 'do' + the subject ...
# 2    Can use inverted auxiliary 'do' + the subject ...
# 3    Can use inverted auxiliary 'do' + the subject ...
# 4    Can use inverted auxiliary 'do' + the subject ...
# ..                                                 ...
# 233  Can use a wide range of linking verbs with com...
# 234  Can use a wide range of linking verbs with com...
# 235  Can use a wide range of linking verbs with com...
# 236  Can use a wide range of linking verbs with com...
# 237  Can use a wide range of linking verbs with com...
#
#                                                Example  \
# 0    Indeed, not only did they teach us useful know...
# 1    Indeed, not only did they teach us useful know...
# 2    Indeed, not only did they teach us useful know...
# 3    Indeed, not only did they teach us useful know...
# 4    Indeed, not only did they teach us useful know...
# ..                                                 ...
# 233  There are indeed many ways of doing this and i...
# 234  There are indeed many ways of doing this and i...
# 235  There are indeed many ways of doing this and i...
# 236  There are indeed many ways of doing this and i...
# 237  There are indeed many ways of doing this and i...
#
#                                           all_examples
# 0    (True, Not only is she a talented pianist, but...
# 1    (False, They not only provide a comfortable st...
# 2    (False, He not only fixed the car, but he also...
# 3    (False, She not only passed the exam, but she ...
# 4    (True, Not only did they read the book, but th...
# ..                                                 ...
# 233  (True, John was exhausted after the long day a...
# 234  (True, The movie seems really interesting but ...
# 235  (True, The book appears complicated at first g...
# 236  (False, This movie can seem really interesting...
# 237  (True, The situation seems hopeless but there ...
#
# [238 rows x 9 columns]

# %% [markdown]
# Split back into two columns

# %%
new_df[['positive', 'example']] = new_df['all_examples'].apply(pd.Series)
new_df.drop(['all_examples'], axis=1, inplace=True)
new_df.head()
# Out:
#      # SuperCategory   SubCategory Level  Lexical Range  \
# 0  273  CONJUNCTIONS  coordinating    C1            NaN
# 1  273  CONJUNCTIONS  coordinating    C1            NaN
# 2  273  CONJUNCTIONS  coordinating    C1            NaN
# 3  273  CONJUNCTIONS  coordinating    C1            NaN
# 4  273  CONJUNCTIONS  coordinating    C1            NaN
#
#                                         guideword  \
# 0  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 1  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 2  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 3  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 4  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
#
#                                     Can-do statement  \
# 0  Can use inverted auxiliary 'do' + the subject ...
# 1  Can use inverted auxiliary 'do' + the subject ...
# 2  Can use inverted auxiliary 'do' + the subject ...
# 3  Can use inverted auxiliary 'do' + the subject ...
# 4  Can use inverted auxiliary 'do' + the subject ...
#
#                                              Example  positive  \
# 0  Indeed, not only did they teach us useful know...      True
# 1  Indeed, not only did they teach us useful know...     False
# 2  Indeed, not only did they teach us useful know...     False
# 3  Indeed, not only did they teach us useful know...     False
# 4  Indeed, not only did they teach us useful know...      True
#
#                                              example
# 0  Not only is she a talented pianist, but she ca...
# 1  They not only provide a comfortable stay, but ...
# 2  He not only fixed the car, but he also gave it...
# 3  She not only passed the exam, but she also rec...
# 4  Not only did they read the book, but they also...

# %% [markdown]
# Save the entire information into a json

# %%
new_df.head()
# Out:
#      # SuperCategory   SubCategory Level  Lexical Range  \
# 0  273  CONJUNCTIONS  coordinating    C1            NaN
# 1  273  CONJUNCTIONS  coordinating    C1            NaN
# 2  273  CONJUNCTIONS  coordinating    C1            NaN
# 3  273  CONJUNCTIONS  coordinating    C1            NaN
# 4  273  CONJUNCTIONS  coordinating    C1            NaN
#
#                                         guideword  \
# 0  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 1  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 2  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 3  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 4  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
#
#                                     Can-do statement  \
# 0  Can use inverted auxiliary 'do' + the subject ...
# 1  Can use inverted auxiliary 'do' + the subject ...
# 2  Can use inverted auxiliary 'do' + the subject ...
# 3  Can use inverted auxiliary 'do' + the subject ...
# 4  Can use inverted auxiliary 'do' + the subject ...
#
#                                              Example  positive  \
# 0  Indeed, not only did they teach us useful know...      True
# 1  Indeed, not only did they teach us useful know...     False
# 2  Indeed, not only did they teach us useful know...     False
# 3  Indeed, not only did they teach us useful know...     False
# 4  Indeed, not only did they teach us useful know...      True
#
#                                              example
# 0  Not only is she a talented pianist, but she ca...
# 1  They not only provide a comfortable stay, but ...
# 2  He not only fixed the car, but he also gave it...
# 3  She not only passed the exam, but she also rec...
# 4  Not only did they read the book, but they also...

# %%
new_df.to_json(JSON_PATH)

# %% [markdown]
# Save into an excel file without the positive label

# %%
new_df['rating'] = 0

new_df.drop('positive', axis=1).to_excel(EXCEL_PATH, index=False)

# %% [markdown]
# After having rated with excel read in the columns

# %%
rating_df = pd.read_excel(EXCEL_PATH)
rating_df.head()
# Out:
#      # SuperCategory   SubCategory Level  Lexical Range  \
# 0  273  CONJUNCTIONS  coordinating    C1            NaN
# 1  273  CONJUNCTIONS  coordinating    C1            NaN
# 2  273  CONJUNCTIONS  coordinating    C1            NaN
# 3  273  CONJUNCTIONS  coordinating    C1            NaN
# 4  273  CONJUNCTIONS  coordinating    C1            NaN
#
#                                         guideword  \
# 0  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 1  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 2  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 3  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 4  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
#
#                                     Can-do statement  \
# 0  Can use inverted auxiliary 'do' + the subject ...
# 1  Can use inverted auxiliary 'do' + the subject ...
# 2  Can use inverted auxiliary 'do' + the subject ...
# 3  Can use inverted auxiliary 'do' + the subject ...
# 4  Can use inverted auxiliary 'do' + the subject ...
#
#                                              Example  \
# 0  Indeed, not only did they teach us useful know...
# 1  Indeed, not only did they teach us useful know...
# 2  Indeed, not only did they teach us useful know...
# 3  Indeed, not only did they teach us useful know...
# 4  Indeed, not only did they teach us useful know...
#
#                                              example  rating
# 0  Not only is she a talented pianist, but she ca...       1
# 1  They not only provide a comfortable stay, but ...       1
# 2  He not only fixed the car, but he also gave it...       1
# 3  She not only passed the exam, but she also rec...       1
# 4  Not only did they read the book, but they also...       2

# %%
source_df = pd.read_json(JSON_PATH)
rating_df['source'] = source_df['positive']
rating_df.head()
# Out:
#      # SuperCategory   SubCategory Level  Lexical Range  \
# 0  273  CONJUNCTIONS  coordinating    C1            NaN
# 1  273  CONJUNCTIONS  coordinating    C1            NaN
# 2  273  CONJUNCTIONS  coordinating    C1            NaN
# 3  273  CONJUNCTIONS  coordinating    C1            NaN
# 4  273  CONJUNCTIONS  coordinating    C1            NaN
#
#                                         guideword  \
# 0  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 1  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 2  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 3  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
# 4  FORM/USE: 'NOT ONLY … BUT ALSO' WITH INVERSION
#
#                                     Can-do statement  \
# 0  Can use inverted auxiliary 'do' + the subject ...
# 1  Can use inverted auxiliary 'do' + the subject ...
# 2  Can use inverted auxiliary 'do' + the subject ...
# 3  Can use inverted auxiliary 'do' + the subject ...
# 4  Can use inverted auxiliary 'do' + the subject ...
#
#                                              Example  \
# 0  Indeed, not only did they teach us useful know...
# 1  Indeed, not only did they teach us useful know...
# 2  Indeed, not only did they teach us useful know...
# 3  Indeed, not only did they teach us useful know...
# 4  Indeed, not only did they teach us useful know...
#
#                                              example  rating  source
# 0  Not only is she a talented pianist, but she ca...       1    True
# 1  They not only provide a comfortable stay, but ...       1   False
# 2  He not only fixed the car, but he also gave it...       1   False
# 3  She not only passed the exam, but she also rec...       1   False
# 4  Not only did they read the book, but they also...       2    True

# %%
rating_df['source'] = rating_df['source'].astype(int) 
rating_df['rating'] = rating_df['rating'] - 1 
rating_df['correct'] = (rating_df['rating'] == rating_df['source'])

# %%
rating_df.groupby('#')['correct'].mean()
# Out:
# #
# 273     0.875000
# 315     0.925000
# 872     0.657895
# 910     0.525000
# 1102    0.975000
# 1104    0.650000
# Name: correct, dtype: float64

# %%
rating_df.groupby(['Level', 'Can-do statement', 'source'])['correct'].mean()
# Out:
# Level  Can-do statement                                                                                                                                                         source
# A1     Can use linking verb 'be' with complements.                                                                                                                              0         1.00
#                                                                                                                                                                                 1         0.95
# A2     Can use the negative form with an increasing range of regular and irregular verbs.                                                                                       0         0.35
#                                                                                                                                                                                 1         1.00
# B1     Can use an increasing range of singular reflexive pronouns with an increasing range of verbs to refer to actions where the subject and object of the verb are the same.  0         0.55
#                                                                                                                                                                                 1         0.50
# B2     Can use a wide range of linking verbs with complements.                                                                                                                  0         0.50
#                                                                                                                                                                                 1         0.80
# C1     Can use inverted auxiliary 'do' + the subject after 'not only', to give focus.                                                                                           0         1.00
#                                                                                                                                                                                 1         0.75
# C2     Can use 'this' with nouns and noun phrases in a narrative to create a sense of immediacy.                                                                                0         1.00
#                                                                                                                                                                                 1         0.85
# Name: correct, dtype: float64
