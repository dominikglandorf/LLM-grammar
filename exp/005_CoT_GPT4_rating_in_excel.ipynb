# %% [markdown]
# ## Exp5: Export to excel for manual rating

# %% [markdown]
# This file exports the augmented dataframe to an excel and reads it back in.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
import config


INPUT_PATH = '../dat/egpaugmented_cot.json'
EXCEL_PATH = '../dat/augmented_examples_shuffled_cot.xlsx'
JSON_PATH = '../dat/augmented_examples_shuffled_cot.json'

# %%
df = pd.read_json(INPUT_PATH)

# %%
df.head()
# Out:
#        # SuperCategory           SubCategory Level  Lexical Range  \
# 923  924      PRONOUNS       subject/ object    A1            NaN
# 924  925      PRONOUNS       subject/ object    A1            3.0
# 334  335   DETERMINERS              quantity    A2            2.0
# 242  243       CLAUSES          subordinated    A2            NaN
# 103  104       ADVERBS  adverbs as modifiers    B1            2.0
#
#                                  guideword  \
# 923       FORM: (OBJECT) WITH PREPOSITION
# 924  FORM: (SUBJECT) 'IT' FOR FIRST PERSON
# 334             FORM: WITH SINGULAR NOUNS
# 242                      FORM/USE: PURPOSE
# 103                            USE: STANCE
#
#                                       Can-do statement  \
# 923  Can use the object pronouns 'me', 'you', 'him'...
# 924  Can use the pronoun 'it' before 'be' to refer ...
# 334  Can use an increasing range of quantifying det...
# 242  Can use a non-finite subordinate clause with '...
# 103  Can use an increasing range of adverbs ('compl...
#
#                                                Example  \
# 923  I really like to learn new words. It's very im...
# 924  Hello Mrs Bishop. It's Clarisse \n\nDear Cris,...
# 334  The new art class starts next Monday and each ...
# 242  To get to my house you'll have to take the 5th...
# 103  I am completely sure. \n\nIt's obviously much ...
#
#                                                 prompt  \
# 923  Create 20 more examples for the grammatical co...
# 924  Create 20 more examples for the grammatical co...
# 334  Create 20 more examples for the grammatical co...
# 242  Create 20 more examples for the grammatical co...
# 103  Create 20 more examples for the grammatical co...
#
#                                     augmented_examples  \
# 923  [She's always there for me., Take this gift to...
# 924  [It's Juan. I'm calling about the job intervie...
# 334  [I have one brother and he is a doctor., There...
# 242  [To improve his speaking skills, he joined an ...
# 103  [Hopefully, I will be able to finish my work o...
#
#                            augmented_negative_examples  \
# 923  [I really like to learn new words. It's very i...
# 924  [Hello Mrs Bishop. My name is Clarisse., Dear ...
# 334  [The new art class starts next Monday and ever...
# 242  [He joined an English conversation club becaus...
# 103  [I am sure with complete confidence., It is mu...
#
#                                 augmented_examples_CoT  \
# 923  [She always sits next to me during class., He ...
# 924  [Hi there, it's Sam., Excuse me, it's Sarah sp...
# 334  [Each student must bring an English book to cl...
# 242  [To improve your English speaking skills, you ...
# 103  [Hopefully, the weather will be nice for our p...
#
#                        augmented_negative_examples_CoT  \
# 923  [She always sits next to me during class., She...
# 924  [Hi there, I am Sam., Excuse me, this is Sarah...
# 334  [Every student must bring a book on English to...
# 242  [If you want to improve your English speaking ...
# 103  [I hope the weather will be nice for our picni...
#
#                                augmented_examples_GPT4  \
# 923  [She baked a cake for him., They always talk a...
# 924  [Good morning, everyone! It's Jake., Hi, did y...
# 334  [I found two kittens in the garden: one black ...
# 242  [To improve your English, try reading books in...
# 103  [Honestly, I think this restaurant serves the ...
#
#                       augmented_negative_examples_GPT4
# 923  [She baked a cake for John., They always talk ...
# 924  [Good morning, everyone! Jake speaking., Hi, d...
# 334  [I found two kittens in the garden: a black on...
# 242  [If you want to improve your English, try read...
# 103  [I think this restaurant serves the best food ...

# %%
df.prompt.iloc[0]
# Out:
# 'Create 20 more examples for the grammatical construction on CEFR level A1 in the category "PRONOUNS: subject/ object" with guideword "FORM: (OBJECT) WITH PREPOSITION " and the rule: "Can use the object pronouns \'me\', \'you\', \'him\', \'her\', \'it\', \'us\' and \'them\' in the object position after prepositions. "\n\nExamples:\n\nI really like to learn new words. It\'s very important for me. \n\nSometimes I go with her. \n\nCan you bring some music so we can listen to it. \n\nI spend my free time with them.\n\nOutput format:\n1. [EXAMPLE 1]\n2. [EXAMPLE 2]'

# %% [markdown]
# Concat all examples, maintaining if they are positive or negative examples and the source.

# %%
df['augmented_examples'] = df['augmented_examples'].apply(lambda examples: list(zip([True] * len(examples), ["GPT3.5"] * len(examples), examples)))
df['augmented_negative_examples'] = df['augmented_negative_examples'].apply(lambda examples: list(zip([False] * len(examples), ["GPT3.5"] * len(examples), examples)))
df['augmented_examples_CoT'] = df['augmented_examples_CoT'].apply(lambda examples: list(zip([True] * len(examples), ["CoT"] * len(examples), examples)))
df['augmented_negative_examples_CoT'] = df['augmented_negative_examples_CoT'].apply(lambda examples: list(zip([False] * len(examples), ["CoT"] * len(examples), examples)))
df['augmented_examples_GPT4'] = df['augmented_examples_GPT4'].apply(lambda examples: list(zip([True] * len(examples), ["GPT4"] * len(examples), examples)))
df['augmented_negative_examples_GPT4'] = df['augmented_negative_examples_GPT4'].apply(lambda examples: list(zip([False] * len(examples), ["GPT4"] * len(examples), examples)))

df['all_examples'] = df['augmented_examples'] + df['augmented_negative_examples'] + df['augmented_examples_CoT'] + df['augmented_negative_examples_CoT'] + df['augmented_examples_GPT4'] + df['augmented_negative_examples_GPT4']
df['all_examples']
# Out:
# 923    [(True, GPT3.5, She's always there for me.), (...
# 924    [(True, GPT3.5, It's Juan. I'm calling about t...
# 334    [(True, GPT3.5, I have one brother and he is a...
# 242    [(True, GPT3.5, To improve his speaking skills...
# 103    [(True, GPT3.5, Hopefully, I will be able to f...
# 413    [(True, GPT3.5, She's taking a flight to Paris...
# 503    [(True, GPT3.5, I may just have the solution t...
# 370    [(True, GPT3.5, By next month, she will have b...
# 454    [(True, GPT3.5, As you can probably guess, I c...
# 521    [(True, GPT3.5, Might it not be better to sche...
# 147    [(True, GPT3.5, The professor spoke so intelli...
# 920    [(True, GPT3.5, As for myself, I find it hard ...
# Name: all_examples, dtype: object

# %% [markdown]
# Create one row per example

# %%
new_df = df.explode('all_examples').drop(['augmented_examples', 'augmented_negative_examples', 'augmented_examples_CoT', 'augmented_negative_examples_CoT', 'augmented_examples_GPT4', 'augmented_negative_examples_GPT4', 'prompt'], axis=1, inplace=False)
new_df = new_df.groupby('#').apply(lambda x: x.sample(frac=1, random_state=config.SEED)).reset_index(drop=True)
new_df
# Out:
#         # SuperCategory           SubCategory Level  Lexical Range  \
# 0     104       ADVERBS  adverbs as modifiers    B1            2.0
# 1     104       ADVERBS  adverbs as modifiers    B1            2.0
# 2     104       ADVERBS  adverbs as modifiers    B1            2.0
# 3     104       ADVERBS  adverbs as modifiers    B1            2.0
# 4     104       ADVERBS  adverbs as modifiers    B1            2.0
# ...   ...           ...                   ...   ...            ...
# 1511  925      PRONOUNS       subject/ object    A1            3.0
# 1512  925      PRONOUNS       subject/ object    A1            3.0
# 1513  925      PRONOUNS       subject/ object    A1            3.0
# 1514  925      PRONOUNS       subject/ object    A1            3.0
# 1515  925      PRONOUNS       subject/ object    A1            3.0
#
#                                   guideword  \
# 0                               USE: STANCE
# 1                               USE: STANCE
# 2                               USE: STANCE
# 3                               USE: STANCE
# 4                               USE: STANCE
# ...                                     ...
# 1511  FORM: (SUBJECT) 'IT' FOR FIRST PERSON
# 1512  FORM: (SUBJECT) 'IT' FOR FIRST PERSON
# 1513  FORM: (SUBJECT) 'IT' FOR FIRST PERSON
# 1514  FORM: (SUBJECT) 'IT' FOR FIRST PERSON
# 1515  FORM: (SUBJECT) 'IT' FOR FIRST PERSON
#
#                                        Can-do statement  \
# 0     Can use an increasing range of adverbs ('compl...
# 1     Can use an increasing range of adverbs ('compl...
# 2     Can use an increasing range of adverbs ('compl...
# 3     Can use an increasing range of adverbs ('compl...
# 4     Can use an increasing range of adverbs ('compl...
# ...                                                 ...
# 1511  Can use the pronoun 'it' before 'be' to refer ...
# 1512  Can use the pronoun 'it' before 'be' to refer ...
# 1513  Can use the pronoun 'it' before 'be' to refer ...
# 1514  Can use the pronoun 'it' before 'be' to refer ...
# 1515  Can use the pronoun 'it' before 'be' to refer ...
#
#                                                 Example  \
# 0     I am completely sure. \n\nIt's obviously much ...
# 1     I am completely sure. \n\nIt's obviously much ...
# 2     I am completely sure. \n\nIt's obviously much ...
# 3     I am completely sure. \n\nIt's obviously much ...
# 4     I am completely sure. \n\nIt's obviously much ...
# ...                                                 ...
# 1511  Hello Mrs Bishop. It's Clarisse \n\nDear Cris,...
# 1512  Hello Mrs Bishop. It's Clarisse \n\nDear Cris,...
# 1513  Hello Mrs Bishop. It's Clarisse \n\nDear Cris,...
# 1514  Hello Mrs Bishop. It's Clarisse \n\nDear Cris,...
# 1515  Hello Mrs Bishop. It's Clarisse \n\nDear Cris,...
#
#                                            all_examples
# 0     (True, GPT3.5, Completely, everything went acc...
# 1     (True, GPT4, Luckily, the traffic wasn't as ba...
# 2     (True, CoT, Basically, we need to follow these...
# 3     (False, CoT, I hope that we'll be able to fini...
# 4     (True, GPT3.5, Hopefully, we will have enough ...
# ...                                                 ...
# 1511  (False, CoT, Sorry to bother you, but I am Mar...
# 1512  (True, CoT, Good evening, it's Michael. Let's ...
# 1513  (True, GPT3.5, It's Jake. I wanted to ask if y...
# 1514             (False, CoT, Good morning, I am Alex.)
# 1515  (True, CoT, Excuse me, it's Maria here, the ne...
#
# [1516 rows x 9 columns]

# %% [markdown]
# Split back into two columns

# %%
new_df[['positive', 'source', 'example']] = new_df['all_examples'].apply(pd.Series)
new_df.drop(['all_examples'], axis=1, inplace=True)
new_df.head()
# Out:
#      # SuperCategory           SubCategory Level  Lexical Range    guideword  \
# 0  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 1  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 2  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 3  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 4  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
#
#                                     Can-do statement  \
# 0  Can use an increasing range of adverbs ('compl...
# 1  Can use an increasing range of adverbs ('compl...
# 2  Can use an increasing range of adverbs ('compl...
# 3  Can use an increasing range of adverbs ('compl...
# 4  Can use an increasing range of adverbs ('compl...
#
#                                              Example  positive  source  \
# 0  I am completely sure. \n\nIt's obviously much ...     False     CoT
# 1  I am completely sure. \n\nIt's obviously much ...     False    GPT4
# 2  I am completely sure. \n\nIt's obviously much ...      True  GPT3.5
# 3  I am completely sure. \n\nIt's obviously much ...      True    GPT4
# 4  I am completely sure. \n\nIt's obviously much ...      True    GPT4
#
#                                              example
# 0  Thankfully, we were able to catch the last tra...
# 1  We need to rethink our strategy if we want to ...
# 2  Sadly, many people are still suffering from po...
# 3  Luckily, the traffic wasn't as bad as I expect...
# 4  Obviously, you need to apologize if you've hur...

# %% [markdown]
# Save the entire information into a json

# %%
new_df.head()
# Out:
#      # SuperCategory           SubCategory Level  Lexical Range    guideword  \
# 0  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 1  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 2  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 3  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 4  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
#
#                                     Can-do statement  \
# 0  Can use an increasing range of adverbs ('compl...
# 1  Can use an increasing range of adverbs ('compl...
# 2  Can use an increasing range of adverbs ('compl...
# 3  Can use an increasing range of adverbs ('compl...
# 4  Can use an increasing range of adverbs ('compl...
#
#                                              Example  positive  source  \
# 0  I am completely sure. \n\nIt's obviously much ...     False     CoT
# 1  I am completely sure. \n\nIt's obviously much ...     False    GPT4
# 2  I am completely sure. \n\nIt's obviously much ...      True  GPT3.5
# 3  I am completely sure. \n\nIt's obviously much ...      True    GPT4
# 4  I am completely sure. \n\nIt's obviously much ...      True    GPT4
#
#                                              example
# 0  Thankfully, we were able to catch the last tra...
# 1  We need to rethink our strategy if we want to ...
# 2  Sadly, many people are still suffering from po...
# 3  Luckily, the traffic wasn't as bad as I expect...
# 4  Obviously, you need to apologize if you've hur...

# %%
new_df.to_json(JSON_PATH)

# %% [markdown]
# Save into an excel file without the positive label and source

# %%
new_df['rating'] = 0

new_df.drop(['positive', 'source'], axis=1).to_excel(EXCEL_PATH, index=False)

# %% [markdown]
# ## Analyse results

# %% [markdown]
# After having rated with excel read in the columns

# %%
rating_df = pd.read_excel(EXCEL_PATH)
rating_df.head()
# Out:
#      # SuperCategory           SubCategory Level  Lexical Range    guideword  \
# 0  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 1  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 2  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 3  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 4  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
#
#                                     Can-do statement  \
# 0  Can use an increasing range of adverbs ('compl...
# 1  Can use an increasing range of adverbs ('compl...
# 2  Can use an increasing range of adverbs ('compl...
# 3  Can use an increasing range of adverbs ('compl...
# 4  Can use an increasing range of adverbs ('compl...
#
#                                              Example  \
# 0  I am completely sure. \n\nIt's obviously much ...
# 1  I am completely sure. \n\nIt's obviously much ...
# 2  I am completely sure. \n\nIt's obviously much ...
# 3  I am completely sure. \n\nIt's obviously much ...
# 4  I am completely sure. \n\nIt's obviously much ...
#
#                                              example  rating Unnamed: 10
# 0  Thankfully, we were able to catch the last tra...       2         NaN
# 1  We need to rethink our strategy if we want to ...       1         NaN
# 2  Sadly, many people are still suffering from po...       2         NaN
# 3  Luckily, the traffic wasn't as bad as I expect...       2         NaN
# 4  Obviously, you need to apologize if you've hur...       2         NaN

# %%
source_df = pd.read_json(JSON_PATH)
rating_df['positive'] = source_df['positive']
rating_df['source'] = source_df['source']
rating_df.head()
# Out:
#      # SuperCategory           SubCategory Level  Lexical Range    guideword  \
# 0  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 1  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 2  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 3  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
# 4  104       ADVERBS  adverbs as modifiers    B1            2.0  USE: STANCE
#
#                                     Can-do statement  \
# 0  Can use an increasing range of adverbs ('compl...
# 1  Can use an increasing range of adverbs ('compl...
# 2  Can use an increasing range of adverbs ('compl...
# 3  Can use an increasing range of adverbs ('compl...
# 4  Can use an increasing range of adverbs ('compl...
#
#                                              Example  \
# 0  I am completely sure. \n\nIt's obviously much ...
# 1  I am completely sure. \n\nIt's obviously much ...
# 2  I am completely sure. \n\nIt's obviously much ...
# 3  I am completely sure. \n\nIt's obviously much ...
# 4  I am completely sure. \n\nIt's obviously much ...
#
#                                              example  rating Unnamed: 10  \
# 0  Thankfully, we were able to catch the last tra...       2         NaN
# 1  We need to rethink our strategy if we want to ...       1         NaN
# 2  Sadly, many people are still suffering from po...       2         NaN
# 3  Luckily, the traffic wasn't as bad as I expect...       2         NaN
# 4  Obviously, you need to apologize if you've hur...       2         NaN
#
#    positive  source
# 0     False     CoT
# 1     False    GPT4
# 2      True  GPT3.5
# 3      True    GPT4
# 4      True    GPT4

# %%
rating_df = rating_df[rating_df['Unnamed: 10']!='X']

# %%
len(rating_df)
# Out:
# 1488

# %% [markdown]
# Let's analyse where these extra examples come from

# %%
# Perform groupby and count
grouped_counts = rating_df.groupby(['Level', '#', 'source', 'positive'])['rating'].count()

# Identify groups with counts greater than 20
groups_with_count_over_20 = grouped_counts[grouped_counts > 20].index

# Filter the original dataset
filtered_df = rating_df.set_index(['Level', '#', 'source', 'positive']).loc[groups_with_count_over_20].reset_index()

# Display the filtered rows
filtered_df.to_excel("../dat/overlength.xlsx", index=False)

# %%
rating_df['positive'] = rating_df['positive'].astype(int) 
rating_df['rating'] = rating_df['rating'] - 1 
rating_df['correct'] = (rating_df['rating'] == rating_df['positive'])

# %% [markdown]
# Mean correctness per prompt strategy

# %%
rating_df.groupby(['source'])['correct'].mean()
# Out:
# source
# CoT       0.793241
# GPT3.5    0.827723
# GPT4      0.960417
# Name: correct, dtype: float64

# %% [markdown]
# Mean correctness per level

# %%
rating_df.groupby(['Level'])['correct'].mean()
# Out:
# Level
# A1    0.746154
# A2    0.816667
# B1    0.869919
# B2    0.995851
# C1    0.826923
# C2    0.908714
# Name: correct, dtype: float64

# %% [markdown]
# Mean correctness per construction in GPT4

# %%
rating_df[rating_df['source']=="GPT4"].groupby(['#'])['correct'].mean()
# Out:
# #
# 104    1.000
# 148    1.000
# 243    0.875
# 335    0.800
# 371    1.000
# 414    0.925
# 455    0.975
# 504    1.000
# 522    0.975
# 921    1.000
# 924    0.975
# 925    1.000
# Name: correct, dtype: float64

# %% [markdown]
# Mean corrctness per group

# %%
rating_df.groupby(['Level', '#', 'source'])['correct'].mean()
# Out:
# Level  #    source
# A1     924  CoT       0.650000
#             GPT3.5    0.475000
#             GPT4      0.975000
#        925  CoT       0.875000
#             GPT3.5    0.550000
#             GPT4      1.000000
# A2     243  CoT       0.725000
#             GPT3.5    0.950000
#             GPT4      0.875000
#        335  CoT       0.775000
#             GPT3.5    0.775000
#             GPT4      0.800000
# B1     104  CoT       0.775000
#             GPT3.5    0.756098
#             GPT4      1.000000
#        414  CoT       0.809524
#             GPT3.5    0.953488
#             GPT4      0.925000
# B2     371  CoT       1.000000
#             GPT3.5    1.000000
#             GPT4      1.000000
#        504  CoT       1.000000
#             GPT3.5    0.975000
#             GPT4      1.000000
# C1     455  CoT       0.750000
#             GPT3.5    0.616667
#             GPT4      0.975000
#        522  CoT       0.750000
#             GPT3.5    1.000000
#             GPT4      0.975000
# C2     148  CoT       0.500000
#             GPT3.5    0.975000
#             GPT4      1.000000
#        921  CoT       0.975610
#             GPT3.5    1.000000
#             GPT4      1.000000
# Name: correct, dtype: float64

# %% [markdown]
# ## Plotting

# %%
pivot_df = rating_df.pivot_table(index=['Level', '#'], columns='source', values='correct')

x_labels = [f"({level})-{num}" for level, num in pivot_df.index]
n_groups = len(pivot_df.index)


bar_width = 0.25
index = np.arange(n_groups)
positions = [index - bar_width, index, index + bar_width]

fig, ax = plt.subplots(figsize=(15, 8))
colors = {"CoT": "red", "GPT3.5": "blue", "GPT4": "green"}
source_averages = rating_df.groupby('source')['correct'].mean()

for pos, source in zip(positions, pivot_df.columns):
    ax.bar(pos, pivot_df[source], bar_width, label=source, color=colors[source])
    ax.axhline(y=source_averages[source], color=colors[source], linestyle='--', label=f"{source} Avg")


ax.set_xlabel('Grammar construction', fontsize=14)
ax.set_ylabel('Correct', fontsize=14)
ax.set_title('Average correctness by Level, Number, and Source', fontsize=16)
ax.set_xticks(index)
ax.set_xticklabels(x_labels, rotation=45)
ax.legend(title="Source")

plt.show()

# %%
rating_df.groupby(['positive', 'source'])['correct'].mean()
# Out:
# positive  source
# 0         CoT       0.731801
#           GPT3.5    0.690566
#           GPT4      0.933333
# 1         CoT       0.859504
#           GPT3.5    0.979167
#           GPT4      0.987500
# Name: correct, dtype: float64

# %%
# Creating a pivot table for easier plotting
new_pivot_df = rating_df.pivot_table(index='positive', columns='source', values='correct')

# Number of unique 'Positive' values
n_groups = len(new_pivot_df.index)

# Creating bar positions for each source
index = np.arange(n_groups)
positions = [index - bar_width, index, index + bar_width]

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

for pos, source in zip(positions, new_pivot_df.columns):
    ax.bar(pos, new_pivot_df[source], bar_width, label=source)

# Setting plot details
ax.set_xlabel('Positive', fontsize=14)
ax.set_ylabel('Correct Mean', fontsize=14)
ax.set_title('Mean Correctness by Positive and Source', fontsize=16)
ax.set_xticks(index)
ax.set_xticklabels(new_pivot_df.index)
ax.legend(title="Source")

plt.show()
